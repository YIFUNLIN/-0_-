# %%
c = ['a', 'b', 'c', 'd', 'e', 'f', 'g']

print(c[:])
print(c[:3])
print(c[3:])
print(c[2:5])
print(c[::2])
print(c[1:6:2])
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f', 'g']
# ['a', 'b', 'c']
# ['d', 'e', 'f', 'g']
# ['c', 'd', 'e']
# ['a', 'c', 'e', 'g']
# ['b', 'd', 'f']

# %%
animal_list = ['dog', 'cat', 'monkey', 'bird', 'elephant']
for i, j in enumerate(animal_list):
  print('item', i, '=', j)
# Out:
# item 0 = dog
# item 1 = cat
# item 2 = monkey
# item 3 = bird
# item 4 = elephant

# %%
index_list = ['a', 'b', 'c', 'd', 'e']
animal_list = ['dog', 'cat', 'monkey', 'bird', 'elephant']
print(list(zip(index_list, animal_list)))
# Out:
# [('a', 'dog'), ('b', 'cat'), ('c', 'monkey'), ('d', 'bird'), ('e', 'elephant')]

# %%
fruits = ['apple', 'peach', 'banana', 'guava', 'papaya']
colors = ['red', 'pink', 'yellow', 'green', 'orange']

for name, color in zip(fruits, colors):
  print(name, 'is', color)
# Out:
# apple is red
# peach is pink
# banana is yellow
# guava is green
# papaya is orange

# %%
fruits = {
'apple': 'red',
'peach': 'pink',
'banana': 'yellow',
'guava': 'green',
'papaya': 'orange'
}

for name, color in fruits.items():
  print(name, 'is', color)
# Out:
# apple is red
# peach is pink
# banana is yellow
# guava is green
# papaya is orange
